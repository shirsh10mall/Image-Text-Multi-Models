# %%
# !pip install datasets
from datasets import Dataset, load_dataset, load_from_disk, concatenate_datasets

from PIL import PngImagePlugin
LARGE_ENOUGH_NUMBER = 100
PngImagePlugin.MAX_TEXT_CHUNK = LARGE_ENOUGH_NUMBER * (1024**2)

from huggingface_hub import notebook_login
from huggingface_hub import login

from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
secret_value_0 = user_secrets.get_secret("SHIRSH_HUGGINGFACE_API_KEY")

login(token=secret_value_0, write_permission=True)
# Out:
# ...
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
import os

os.makedirs("/kaggle/working/Image_Captioning_GCC_Embeddings", exist_ok=True)
os.makedirs("/kaggle/working/Image_Captioning_GCC_Embeddings/train", exist_ok=True)

# %%
import shutil

# %%
shutil.copy("/kaggle/input/gcc-embeddings/Image_Captioning_GCC_Embeddings/dataset_dict.json", "/kaggle/working/Image_Captioning_GCC_Embeddings")
# Out:
# '/kaggle/working/Image_Captioning_GCC_Embeddings/dataset_dict.json'

# %%
shutil.copy( "/kaggle/input/gcc-embeddings/Image_Captioning_GCC_Embeddings/train/dataset.arrow", "/kaggle/working/Image_Captioning_GCC_Embeddings/train" )
# Out:
# '/kaggle/working/Image_Captioning_GCC_Embeddings/train/dataset.arrow'

# %%
shutil.copy( "/kaggle/input/gcc-embeddings/Image_Captioning_GCC_Embeddings/train/dataset_info.json", "/kaggle/working/Image_Captioning_GCC_Embeddings/train" )
# Out:
# '/kaggle/working/Image_Captioning_GCC_Embeddings/train/dataset_info.json'

# %%
shutil.copy( "/kaggle/input/gcc-embeddings/Image_Captioning_GCC_Embeddings/train/state.json", "/kaggle/working/Image_Captioning_GCC_Embeddings/train" )
# Out:
# '/kaggle/working/Image_Captioning_GCC_Embeddings/train/state.json'

# %%
dataset = load_from_disk("/kaggle/working/Image_Captioning_GCC_Embeddings")
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['caption', 'image_data', 'image_embeddings', 'text_embeddings'],
#         num_rows: 143134
#     })
# })

# %%
# dataset = dataset.filter(lambda instance, index: index<1000 , with_indices=True)
# dataset.save_to_disk("/kaggle/working/Image_Captioning_GCC_Embeddings_1k")
# dataset
# Out:
# ...
# Flattening the indices:   0%|          | 0/1 [00:00<?, ?ba/s]
# DatasetDict({
#     train: Dataset({
#         features: ['caption', 'image_data', 'image_embeddings', 'text_embeddings'],
#         num_rows: 1000
#     })
# })

# %%
dataset.push_to_hub("shirsh10mall/Image_Captioning_GCC_Embeddings")

# %%
# shutil.rmtree("/kaggle/working/Image_Captioning_GCC_Embeddings")
